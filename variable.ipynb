# %% [markdown]
# <a href="https://colab.research.google.com/github/PRABHVEERSINGH17/2023a1r109king/blob/main/variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#variable -> variable is a container to store information and retrieve it later
x = 10
x
# Out:
# 10

# %%
#Rules for naming variables
#first rule == starting position of variable are letter or under score
#second rule --- remaining part of variable are letter , underscore or number
my_city = " Jammu"
my_city
# Out:
# ' Jammu'

# %%
_mycity = " Shimla "
_mycity
# Out:
# ' Shimla '

# %%
my_city1 = " New Delhi "
my_city1
# Out:
# ' New Delhi '

# %%
# variable cannot contain any space or specific symbol
my@city = "Brailley"
my@city
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-2795831263.py in <cell line: 0>()
# ----> 1 my@city
#
# NameError: name 'my' is not defined
